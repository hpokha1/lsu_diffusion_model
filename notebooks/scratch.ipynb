# %% [markdown]
# # Scratch

# %% [markdown]
# A notebook for wxploring Python, Jupyter, etc.

# %%
D = 100
d = 50

# %%
D
# Out:
# 100

# %%
d
# Out:
# 50

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# D          int        100
# Lx         int        3
# d          int        50
# dx         float      0.5
# np         module     <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# numpy      module     <module 'numpy' from '/op<...>kages/numpy/__init__.py'>
# nx         int        6
# x          ndarray    6: 6 elems, type `float64`, 48 bytes
# x1         ndarray    7: 7 elems, type `float64`, 56 bytes

# %%
import numpy as np

# %% [markdown]
#     Next, set up the model grid with a NumPy aray

# %%
Lx = 8
dx = 0.5
x = np.arange(start=0, stop=Lx, step = dx)
nx =  len(x)

# %%
nx
# Out:
# 16

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ,
#        6.5, 7. , 7.5])

# %%
x1 = np.linspace(start=0, stop=Lx, num=7, endpoint =True)

# %%
x1
# Out:
# array([0.        , 1.33333333, 2.66666667, 4.        , 5.33333333,
#        6.66666667, 8.        ])

# %%
C = np. zeros_like(x)
C_left =  500
C_right =  0
C[x <= Lx//2] = C_left
C[x > Lx//2] = C_right

# %%
C
# Out:
# array([500., 500., 500., 500., 500., 500., 500., 500., 500.,   0.,   0.,
#          0.,   0.,   0.,   0.,   0.])

# %%
C[-1]
# Out:
# np.float64(0.0)

# %%
x[-1]
# Out:
# np.float64(7.5)

# %%
x[-2]
# Out:
# np.float64(7.0)

# %%
nx = len(x)
nx
# Out:
# 16
